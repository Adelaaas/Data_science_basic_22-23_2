# %%
import numpy as np
import matplotlib.pyplot as plt
#350 350

# %%
img = np.zeros((350, 350,3),dtype='uint8')
img

# %%
img[:,:,:]=(255,255,0)

# %%
img[:50,:,:]=(0,0,0)
img[:,:50,:]=(0,0,0)
img[300:,:,:]=(0,0,0)
img[:,300:,:]=(0,0,0)
#img[:,:,:]=(0,0,0)

# %%
plt.imshow(img)
plt.show()

# %%
shah = np.zeros((8, 8,3),dtype='uint8')
shah

# %%
shah[:,:,:]=(255,255,255)

# %%
shah[0::2,0::2,:]=(0,0,0)
shah[1::2,1::2,:]=(0,0,0)

# %%
plt.imshow(shah)
plt.show()
