# %%
import numpy as np
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = np.zeros( (350,200,3), dtype=np.uint8)

# %%
img[:350,:200,:3]=76,57,127

# %%
img[0:10,:,:] = 204,10,10
img[:,0:10,:] = 204,10,10
img[340:350,:,:] = 204,10,10
img[:,190:,:] = 204,10,10

# %%
plt.imshow(img)
plt.show()

# %%
img2 = np.zeros( (8,8,3), dtype=np.uint8)

# %%
img2[:,:,:] = 229,229,229
plt.imshow(img2)
plt.show()

# %%
plt.imshow(img2)
plt.show()

# %%
img2[0::2,0::2,:] = 0,0,0

# %%
img2[1::2,1::2,:] = 0,0,0
