# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Price_euros_train.csv")
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df['Weight'] = df['Weight'].str.replace('kg','')
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df['Weight'] = pd.to_numeric(df['Weight'])

# %%
df['Ram'] = pd.to_numeric(df['Ram'])

# %%
df['GHZ'] = df['Cpu'].str.split()
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df["GHZ1"] = df["GHZ"]

# %%
for i in range(1108):
  df['GHZ1'][i] = df['GHZ'][i][-1]
df
# Out:
# <ipython-input-107-270cd8db8d69>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GHZ1'][i] = df['GHZ'][i][-1]
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# ...

# %%
df = df.drop(columns = ["GHZ"])
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df['GHZ1'] = df['GHZ1'].str.replace('GHz','')
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df['GHZ1'] = pd.to_numeric(df['GHZ1'])
df
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
df["CPUType"] = df["Cpu"]

# %%
for i in range(1108):
  df['CPUType'][i] = df['Cpu'].str.split()[i][0]
df
# Out:
# <ipython-input-112-5fa356c8d5ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CPUType'][i] = df['Cpu'].str.split()[i][0]
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                429
# 1366x768                                         241
# IPS Panel Full HD 1920x1080                      191
# IPS Panel Full HD / Touchscreen 1920x1080         46
# Full HD / Touchscreen 1920x1080                   36
# 1600x900                                          19
# Quad HD+ / Touchscreen 3200x1800                  15
# Touchscreen 1366x768                              12
# IPS Panel 4K Ultra HD 3840x2160                    9
# 4K Ultra HD / Touchscreen 3840x2160                9
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              6
# IPS Panel 1366x768                                 6
# Touchscreen 2256x1504                              5
# IPS Panel Retina Display 2304x1440                 5
# IPS Panel Retina Display 2560x1600                 5
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
df = df.drop(columns= ["laptop_ID"])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
model = LabelEncoder()
df['Company'] = model.fit_transform(df['Company'])
df['Company']
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1103    2
# 1104    9
# 1105    9
# 1106    7
# 1107    2
# Name: Company, Length: 1108, dtype: int64

# %%
df = df.drop(columns = ['Product'])
df
# Out:
#       Company            TypeName  Inches  \
# 0           1           Ultrabook    13.3
# 1           1           Ultrabook    15.4
# 2           1           Ultrabook    13.3
# 3           0            Notebook    15.6
# 4           1           Ultrabook    15.4
# ...       ...                 ...     ...
# 1103        2            Notebook    15.6
# 1104        9  2 in 1 Convertible    14.0
# 1105        9            Notebook    14.0
# 1106        7            Notebook    15.6
# 1107        2            Notebook    15.6
#
#                                ScreenResolution  \
# 0                                      1440x900
# 1            IPS Panel Retina Display 2880x1800
# 2            IPS Panel Retina Display 2560x1600
# 3                                      1366x768
# 4            IPS Panel Retina Display 2880x1800
# ...                                         ...
# 1103                                   1366x768
# 1104  IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
model1 = LabelEncoder()
df['TypeName'] = model1.fit_transform(df['TypeName'])
df['TypeName']
# Out:
# 0       4
# 1       4
# 2       4
# 3       3
# 4       4
#        ..
# 1103    3
# 1104    0
# 1105    3
# 1106    3
# 1107    3
# Name: TypeName, Length: 1108, dtype: int64

# %%
model2 = LabelEncoder()
df['CPUType'] = model2.fit_transform(df['CPUType'])
df['CPUType']
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1103    1
# 1104    1
# 1105    1
# 1106    1
# 1107    1
# Name: CPUType, Length: 1108, dtype: int64

# %%
model3 = LabelEncoder()
df['ScreenResolution'] = model3.fit_transform(df['ScreenResolution'])
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  \
# 0           1         4    13.3                 1
# 1           1         4    15.4                24
# 2           1         4    13.3                22
# 3           0         3    15.6                 0
# 4           1         4    15.4                24
# ...       ...       ...     ...               ...
# 1103        2         3    15.6                 0
# 1104        9         0    14.0                13
# 1105        9         3    14.0                 0
# 1106        7         3    15.6                 0
# 1107        2         3    15.6                 0
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 1                     Intel Core i7 2.7GHz   16            512GB SSD
# 2                     Intel Core i5 3.1GHz    8            256GB SSD
# 3                  AMD A9-Series 9420 3GHz    4            500GB HDD
# ...

# %%
model4 = LabelEncoder()
df['OpSys'] = model4.fit_transform(df['OpSys'])
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  \
# 0           1         4    13.3                 1
# 1           1         4    15.4                24
# 2           1         4    13.3                22
# 3           0         3    15.6                 0
# 4           1         4    15.4                24
# ...       ...       ...     ...               ...
# 1103        2         3    15.6                 0
# 1104        9         0    14.0                13
# 1105        9         3    14.0                 0
# 1106        7         3    15.6                 0
# 1107        2         3    15.6                 0
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 1                     Intel Core i7 2.7GHz   16            512GB SSD
# 2                     Intel Core i5 3.1GHz    8            256GB SSD
# 3                  AMD A9-Series 9420 3GHz    4            500GB HDD
# ...

# %%
df = df.drop(columns = ["Cpu"])

# %%
df["MemoryType"] = df["Memory"]

# %%
for i in range(1108):
  df['MemoryType'][i] = df['Memory'].str.split()[i][-1]
df
# Out:
# <ipython-input-129-5b8967d9168b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MemoryType'][i] = df['Memory'].str.split()[i][-1]
#       Company  TypeName  Inches  ScreenResolution  Ram               Memory  \
# 0           1         4    13.3                 1    8  128GB Flash Storage
# 1           1         4    15.4                24   16            512GB SSD
# 2           1         4    13.3                22    8            256GB SSD
# 3           0         3    15.6                 0    4            500GB HDD
# 4           1         4    15.4                24   16  256GB Flash Storage
# ...       ...       ...     ...               ...  ...                  ...
# 1103        2         3    15.6                 0    4            500GB HDD
# ...

# %%
df["Space"] = df["Memory"]

# %%
for i in range(1108):
  df['Space'][i] = df['Memory'].str.split()[i][0]
df
# Out:
# <ipython-input-132-c5ca73309a59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Space'][i] = df['Memory'].str.split()[i][0]
#       Company  TypeName  Inches  ScreenResolution  Ram               Memory  \
# 0           1         4    13.3                 1    8  128GB Flash Storage
# 1           1         4    15.4                24   16            512GB SSD
# 2           1         4    13.3                22    8            256GB SSD
# 3           0         3    15.6                 0    4            500GB HDD
# 4           1         4    15.4                24   16  256GB Flash Storage
# ...       ...       ...     ...               ...  ...                  ...
# 1103        2         3    15.6                 0    4            500GB HDD
# ...

# %%
model5 = LabelEncoder()
df['MemoryType'] = model5.fit_transform(df['MemoryType'])
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  Ram               Memory  \
# 0           1         4    13.3                 1    8  128GB Flash Storage
# 1           1         4    15.4                24   16            512GB SSD
# 2           1         4    13.3                22    8            256GB SSD
# 3           0         3    15.6                 0    4            500GB HDD
# 4           1         4    15.4                24   16  256GB Flash Storage
# ...       ...       ...     ...               ...  ...                  ...
# 1103        2         3    15.6                 0    4            500GB HDD
# 1104        9         0    14.0                13    4            128GB SSD
# 1105        9         3    14.0                 0    2   64GB Flash Storage
# 1106        7         3    15.6                 0    6              1TB HDD
# 1107        2         3    15.6                 0    4            500GB HDD
#
# ...

# %%
df['Space'] = df['Space'].str.replace('GB','000')
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  Ram               Memory  \
# 0           1         4    13.3                 1    8  128GB Flash Storage
# 1           1         4    15.4                24   16            512GB SSD
# 2           1         4    13.3                22    8            256GB SSD
# 3           0         3    15.6                 0    4            500GB HDD
# 4           1         4    15.4                24   16  256GB Flash Storage
# ...       ...       ...     ...               ...  ...                  ...
# 1103        2         3    15.6                 0    4            500GB HDD
# 1104        9         0    14.0                13    4            128GB SSD
# 1105        9         3    14.0                 0    2   64GB Flash Storage
# 1106        7         3    15.6                 0    6              1TB HDD
# 1107        2         3    15.6                 0    4            500GB HDD
#
# ...

# %%
df['Space'] = df['Space'].str.replace('TB','000000')
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  Ram               Memory  \
# 0           1         4    13.3                 1    8  128GB Flash Storage
# 1           1         4    15.4                24   16            512GB SSD
# 2           1         4    13.3                22    8            256GB SSD
# 3           0         3    15.6                 0    4            500GB HDD
# 4           1         4    15.4                24   16  256GB Flash Storage
# ...       ...       ...     ...               ...  ...                  ...
# 1103        2         3    15.6                 0    4            500GB HDD
# 1104        9         0    14.0                13    4            128GB SSD
# 1105        9         3    14.0                 0    2   64GB Flash Storage
# 1106        7         3    15.6                 0    6              1TB HDD
# 1107        2         3    15.6                 0    4            500GB HDD
#
# ...

# %%
df['Space'] = pd.to_numeric(df['Space'])

# %%
df = df.drop(columns = ["Memory"])
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  Ram  \
# 0           1         4    13.3                 1    8
# 1           1         4    15.4                24   16
# 2           1         4    13.3                22    8
# 3           0         3    15.6                 0    4
# 4           1         4    15.4                24   16
# ...       ...       ...     ...               ...  ...
# 1103        2         3    15.6                 0    4
# 1104        9         0    14.0                13    4
# 1105        9         3    14.0                 0    2
# 1106        7         3    15.6                 0    6
# 1107        2         3    15.6                 0    4
#
#                                Gpu  OpSys  Weight  Price_euros  GHZ1  CPUType  \
# 0           Intel HD Graphics 6000      8    1.34       898.94   1.8        1
# 1               AMD Radeon Pro 455      8    1.83      2537.45   2.7        1
# ...

# %%
df["GpuType"] = df["Gpu"]

# %%
for i in range(1108):
  df['GpuType'][i] = df['Gpu'].str.split()[i][1]
df
# Out:
# <ipython-input-139-673280dfe858>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GpuType'][i] = df['Gpu'].str.split()[i][1]
#       Company  TypeName  Inches  ScreenResolution  Ram  \
# 0           1         4    13.3                 1    8
# 1           1         4    15.4                24   16
# 2           1         4    13.3                22    8
# 3           0         3    15.6                 0    4
# 4           1         4    15.4                24   16
# ...       ...       ...     ...               ...  ...
# 1103        2         3    15.6                 0    4
# 1104        9         0    14.0                13    4
# 1105        9         3    14.0                 0    2
# 1106        7         3    15.6                 0    6
# ...

# %%
df = df.drop(columns = ["Gpu"])

# %%
model6 = LabelEncoder()
df['GpuType'] = model5.fit_transform(df['GpuType'])
df
# Out:
#       Company  TypeName  Inches  ScreenResolution  Ram  OpSys  Weight  \
# 0           1         4    13.3                 1    8      8    1.34
# 1           1         4    15.4                24   16      8    1.83
# 2           1         4    13.3                22    8      8    1.37
# 3           0         3    15.6                 0    4      5    2.10
# 4           1         4    15.4                24   16      3    2.04
# ...       ...       ...     ...               ...  ...    ...     ...
# 1103        2         3    15.6                 0    4      5    2.20
# 1104        9         0    14.0                13    4      5    1.80
# 1105        9         3    14.0                 0    2      5    1.50
# 1106        7         3    15.6                 0    6      5    2.19
# 1107        2         3    15.6                 0    4      5    2.20
#
#       Price_euros  GHZ1  CPUType  MemoryType      Space  GpuType
# ...

# %%
df['Weight'] = df['Weight'].fillna(df['Weight'].mean())

# %%
X = df.drop(["Price_euros"],axis = 1)
Y = df['Price_euros']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)
model7 = LinearRegression()
model7.fit(X_train, y_train)
pred = model7.predict(X_test)

# %%
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('R2 score:', r2_score(y_test, pred))
# Out:
# Mean Absolute Error: 274.51472006589984
# Mean Squared Error: 150863.66591210972
# R2 score: 0.661251470139997

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
scores = []
for i in range(1,20):
    score = {}
    knn = KNeighborsRegressor(i)
    knn.fit(X_train,y_train)
    answers = knn.predict(X_test)
    
    score['k'] = i
    score['MSE'] = mean_squared_error(y_test, answers)
    score['MAE'] = mean_absolute_error(y_test, answers)
    score['R2'] = r2_score(y_test, answers)
    
    scores.append(score)

scores = pd.DataFrame(scores)
scores
# Out:
#      k            MSE         MAE        R2
# 0    1  227719.823724  281.152312  0.488679
# 1    2  186736.547595  274.979895  0.580703
# 2    3  159721.044757  264.882533  0.641363
# 3    4  161418.298283  269.642965  0.637552
# 4    5  165574.301635  271.691285  0.628220
# 5    6  165373.909961  277.131902  0.628670
# 6    7  162795.473287  278.932484  0.634460
# 7    8  162169.687516  282.851363  0.635865
# 8    9  168307.086361  289.795055  0.622084
# 9   10  171242.448379  290.349643  0.615493
# 10  11  173998.941749  290.979468  0.609304
# 11  12  175217.356553  294.403188  0.606568
# 12  13  178448.185121  298.463326  0.599313
# 13  14  181753.246995  301.946240  0.591892
# 14  15  182429.555276  301.596785  0.590374
# 15  16  184727.769834  302.042676  0.585213
# 16  17  187607.870796  303.633909  0.578746
# 17  18  189786.077624  305.815617  0.573855
# 18  19  190935.160036  307.477408  0.571275

# %%
modelknn = KNeighborsRegressor(3)
modelknn.fit(X,Y)
prediction = modelknn.predict(X_test)

# %%
print(mean_squared_error(y_test,prediction))
print(mean_absolute_error(y_test,prediction))
print(r2_score(y_test, prediction))
# Out:
# 71433.38445855855
# 169.33634634634632
# 0.8396038315656577

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
clf = DecisionTreeRegressor(random_state=1)
clf.fit(X_train, y_train)
y_pred_tree = clf.predict(X_test)

# %%
print(mean_squared_error(y_test,y_pred_tree))
print(mean_absolute_error(y_test,y_pred_tree))
print(r2_score(y_test, y_pred_tree))
# Out:
# 202473.27388836333
# 263.3028678678678
# 0.5453675114484982

# %%
df1=pd.read_csv("/content/drive/MyDrive/Price_euros_test.csv")
df1
# Out:
#      laptop_ID Company           Product            TypeName  Inches  \
# 0           86    Acer          Aspire 3            Notebook    15.6
# 1         1249   Razer         Blade Pro              Gaming    14.0
# 2          122    Asus      VivoBook S15            Notebook    15.6
# 3          993    Asus  Rog GL753VE-DS74              Gaming    17.3
# 4          739    Dell     Inspiron 3567            Notebook    15.6
# ..         ...     ...               ...                 ...     ...
# 190        876      HP       Probook 450            Notebook    15.6
# 191        282    Acer   Aspire A515-51G            Notebook    15.6
# 192        528      HP      Spectre X360           Ultrabook    13.3
# 193       1204    Dell     Inspiron 5578  2 in 1 Convertible    15.6
# 194        386      HP    Omen 17-w212nv              Gaming    17.3
#
#                     ScreenResolution                          Cpu   Ram  \
# ...

# %%
df1['Weight'] = df1['Weight'].str.replace('kg','')
df1
# Out:
#      laptop_ID Company           Product            TypeName  Inches  \
# 0           86    Acer          Aspire 3            Notebook    15.6
# 1         1249   Razer         Blade Pro              Gaming    14.0
# 2          122    Asus      VivoBook S15            Notebook    15.6
# 3          993    Asus  Rog GL753VE-DS74              Gaming    17.3
# 4          739    Dell     Inspiron 3567            Notebook    15.6
# ..         ...     ...               ...                 ...     ...
# 190        876      HP       Probook 450            Notebook    15.6
# 191        282    Acer   Aspire A515-51G            Notebook    15.6
# 192        528      HP      Spectre X360           Ultrabook    13.3
# 193       1204    Dell     Inspiron 5578  2 in 1 Convertible    15.6
# 194        386      HP    Omen 17-w212nv              Gaming    17.3
#
#                     ScreenResolution                          Cpu   Ram  \
# ...

# %%
df1['Ram'] = df1['Ram'].str.replace('GB','')

# %%
df1['Weight'] = pd.to_numeric(df1['Weight'])

# %%
df1['Ram'] = pd.to_numeric(df1['Ram'])

# %%
df1['GHZ'] = df1['Cpu'].str.split()

# %%
df1["GHZ1"] = df1["GHZ"]

# %%
for i in range(195):
  df1['GHZ1'][i] = df1['GHZ'][i][-1]
df1
# Out:
# <ipython-input-203-7735afaa7116>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GHZ1'][i] = df1['GHZ'][i][-1]
#      laptop_ID Company           Product            TypeName  Inches  \
# 0           86    Acer          Aspire 3            Notebook    15.6
# 1         1249   Razer         Blade Pro              Gaming    14.0
# 2          122    Asus      VivoBook S15            Notebook    15.6
# 3          993    Asus  Rog GL753VE-DS74              Gaming    17.3
# 4          739    Dell     Inspiron 3567            Notebook    15.6
# ..         ...     ...               ...                 ...     ...
# 190        876      HP       Probook 450            Notebook    15.6
# 191        282    Acer   Aspire A515-51G            Notebook    15.6
# ...

# %%
df1 = df1.drop(columns = ["GHZ"])

# %%
df1['GHZ1'] = df1['GHZ1'].str.replace('GHz','')

# %%
df1['GHZ1'] = pd.to_numeric(df1['GHZ1'])

# %%
df1["CPUType"] = df1["Cpu"]

# %%
for i in range(195):
  df1['CPUType'][i] = df1['Cpu'].str.split()[i][0]
# Out:
# <ipython-input-208-9a9b3783d620>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CPUType'][i] = df1['Cpu'].str.split()[i][0]

# %%
df1 = df1.drop(columns= ["laptop_ID"])

# %%
model11 = LabelEncoder()
df1['Company'] = model11.fit_transform(df1['Company'])

# %%
df1 = df1.drop(columns = ['Product'])

# %%
model12 = LabelEncoder()
df1['TypeName'] = model12.fit_transform(df1['TypeName'])

# %%
model13 = LabelEncoder()
df1['CPUType'] = model13.fit_transform(df1['CPUType'])

# %%
model14 = LabelEncoder()
df1['ScreenResolution'] = model14.fit_transform(df1['ScreenResolution'])

# %%
model15 = LabelEncoder()
df1['OpSys'] = model15.fit_transform(df1['OpSys'])

# %%
df1 = df1.drop(columns = ["Cpu"])

# %%
df1["MemoryType"] = df1["Memory"]

# %%
for i in range(195):
  df1['MemoryType'][i] = df1['Memory'].str.split()[i][-1]
# Out:
# <ipython-input-218-09ae4d15c6e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MemoryType'][i] = df1['Memory'].str.split()[i][-1]

# %%
df1["Space"] = df1["Memory"]

# %%
for i in range(195):
  df1['Space'][i] = df1['Memory'].str.split()[i][0]
# Out:
# <ipython-input-220-fc6c9c135be1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Space'][i] = df1['Memory'].str.split()[i][0]

# %%
model16 = LabelEncoder()
df1['MemoryType'] = model16.fit_transform(df1['MemoryType'])
df1
# Out:
#      Company  TypeName  Inches  ScreenResolution  Ram                Memory  \
# 0          0         3    15.6                 0    4               1TB HDD
# 1         12         1    14.0                 7   16               1TB SSD
# 2          2         3    15.6                 7    8             256GB SSD
# 3          2         1    17.3                 7   16  256GB SSD +  1TB HDD
# 4          4         3    15.6                 0   12               1TB HDD
# ..       ...       ...     ...               ...  ...                   ...
# 190        5         3    15.6                 7    4             500GB HDD
# 191        0         3    15.6                12    8               1TB HDD
# 192        5         4    13.3                12    8             256GB SSD
# 193        4         0    15.6                 6   16             512GB SSD
# 194        5         1    17.3                12    8  128GB SSD +  1TB HDD
#
# ...

# %%
df1['Space'] = df1['Space'].str.replace('GB','000')

# %%
df1['Space'] = df1['Space'].str.replace('TB','000000')

# %%
df1['Space'] = pd.to_numeric(df1['Space'])

# %%
df1 = df1.drop(columns = ["Memory"])

# %%
df1["GpuType"] = df1["Gpu"]

# %%
for i in range(195):
  df1['GpuType'][i] = df1['Gpu'].str.split()[i][1]
# Out:
# <ipython-input-227-6395042a014f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GpuType'][i] = df1['Gpu'].str.split()[i][1]

# %%
df1 = df1.drop(columns = ["Gpu"])

# %%
model17 = LabelEncoder()
df1['GpuType'] = model17.fit_transform(df1['GpuType'])

# %%
df1.isna().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# OpSys               0
# Weight              4
# GHZ1                0
# CPUType             0
# MemoryType          0
# Space               0
# GpuType             0
# dtype: int64

# %%
df1['Weight'] = df1['Weight'].fillna(df1['Weight'].mean())

# %%
answersknn = modelknn.predict(df1)

# %%
df2 = pd.DataFrame(columns = ["Price_euros"])
df2["Price_euros"] = answersknn
df2
# Out:
#      Price_euros
# 0     399.333333
# 1    1967.670000
# 2     931.966667
# 3    1739.000000
# 4     570.673333
# ..           ...
# 190   459.663333
# 191   636.666667
# 192  1406.000000
# 193  1575.753333
# 194  1129.000000
#
# [195 rows x 1 columns]

# %%
df2 = df2.reset_index()

# %%
df2.to_csv("Test.csv",index = False)

# %%
df2
# Out:
#      index  Price_euros
# 0        0   399.333333
# 1        1  1967.670000
# 2        2   931.966667
# 3        3  1739.000000
# 4        4   570.673333
# ..     ...          ...
# 190    190   459.663333
# 191    191   636.666667
# 192    192  1406.000000
# 193    193  1575.753333
# 194    194  1129.000000
#
# [195 rows x 2 columns]

# %%
answerstree = clf.predict(df1)

# %%
df3 = pd.DataFrame(columns = ["Price_euros"])
df3["Price_euros"] = answerstree
df3
# Out:
#      Price_euros
# 0          403.0
# 1         2599.0
# 2         1199.0
# 3         1591.0
# 4          739.0
# ..           ...
# 190        519.0
# 191        647.0
# 192       1458.0
# 193       2397.0
# 194        889.0
#
# [195 rows x 1 columns]

# %%
df3 = df3.reset_index()

# %%
df3.to_csv("Test2.csv",index = False)

# %%
answersreg = model7.predict(df1)

# %%
df4 = pd.DataFrame(columns = ["Price_euros"])
df4["Price_euros"] = answersreg
df4
# Out:
#      Price_euros
# 0     221.681882
# 1    1833.810319
# 2     873.858968
# 3    1688.052600
# 4    1195.634498
# ..           ...
# 190   591.018201
# 191   715.131980
# 192  1345.493659
# 193  1714.697013
# 194  1113.281945
#
# [195 rows x 1 columns]

# %%
df4 = df4.reset_index()

# %%
df4.to_csv("Test3.csv",index = False)
