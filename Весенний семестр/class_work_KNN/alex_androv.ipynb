# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas as pd
od.download("https://www.kaggle.com/competitions/hotel-booking-demand-3")
# Out:
# Skipping, found downloaded files in "./hotel-booking-demand-3" (use force=True to force download)

# %%
train_data=pd.read_csv("/content/hotel-booking-demand-3/train_final.csv")
train_data=train_data.drop(["country"],axis=1)
y=train_data["is_canceled"]
x=train_data.drop(["is_canceled"],axis=1)
train_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0          3               2016           February
# 1    City Hotel            1         50               2016           November
# 2    City Hotel            0         14               2015          September
# 3    City Hotel            0         18               2015           December
# 4    City Hotel            1        263               2016          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                         7                         12
# 1                        47                         18
# 2                        37                          7
# 3                        50                          6
# 4                        40                         29
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     2       2  ...
# ...

# %%
test_final=pd.read_csv("/content/hotel-booking-demand-3/test_final.csv")
test_final=test_final.drop(["country"],axis=1)
from sklearn.preprocessing import MinMaxScaler
model3=MinMaxScaler()
xx_columns=train_data.columns
xx_new=model3.fit_transform(test_final)
xx_new=pd.DataFrame(xx_new,columns=xx_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-6aef93426413> in <module>
#       2 model3=MinMaxScaler()
#       3 xx_columns=train_data.columns
# ----> 4 xx_new=model3.fit_transform(test_final)
#       5 xx_new=pd.DataFrame(xx_new,columns=xx_columns)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44638 entries, 0 to 44637
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           44638 non-null  object
#  1   is_canceled                     44638 non-null  int64
#  2   lead_time                       44638 non-null  int64
#  3   arrival_date_year               44638 non-null  int64
#  4   arrival_date_month              44638 non-null  object
#  5   arrival_date_week_number        44638 non-null  int64
#  6   arrival_date_day_of_month       44638 non-null  int64
#  7   stays_in_weekend_nights         44638 non-null  int64
#  8   stays_in_week_nights            44638 non-null  int64
#  9   adults                          44638 non-null  int64
#  10  children                        44638 non-null  float64
#  11  babies                          44638 non-null  int64
# ...

# %%
X_columns=train_data.columns
for column in X_columns:
    print(train_data[column].value_counts())

# %%
print(train_data.isna().sum())
print(train_data.info())
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

model1=LabelEncoder()
train_data["reservation_status_date"]=model1.fit_transform(train_data["reservation_status_date"])
train_data["arrival_date_month"]=model1.fit_transform(train_data["arrival_date_month"])
train_data["meal"]=model1.fit_transform(train_data["meal"])
train_data["market_segment"]=model1.fit_transform(train_data["market_segment"])
train_data["distribution_channel"]=model1.fit_transform(train_data["distribution_channel"])
train_data["reserved_room_type"]=model1.fit_transform(train_data["reserved_room_type"])
train_data["assigned_room_type"]=model1.fit_transform(train_data["assigned_room_type"])
train_data["deposit_type"]=model1.fit_transform(train_data["deposit_type"])
train_data["customer_type"]=model1.fit_transform(train_data["customer_type"])
train_data["assigned_room_type"]=model1.fit_transform(train_data["assigned_room_type"])
train_data["assigned_room_type"]=model1.fit_transform(train_data["assigned_room_type"])
train_data["reservation_status_date"]=model1.fit_transform(train_data["reservation_status_date"])
train_data["hotel"]=model1.fit_transform(train_data["hotel"])

# %%
test_final=pd.read_csv("/content/hotel-booking-demand-3/test_final.csv")
test_final=test_final.drop(["country"],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

model1=LabelEncoder()
test_final["reservation_status_date"]=model1.fit_transform(test_final["reservation_status_date"])
test_final["arrival_date_month"]=model1.fit_transform(test_final["arrival_date_month"])
test_final["meal"]=model1.fit_transform(test_final["meal"])
test_final["market_segment"]=model1.fit_transform(test_final["market_segment"])
test_final["distribution_channel"]=model1.fit_transform(test_final["distribution_channel"])
test_final["reserved_room_type"]=model1.fit_transform(test_final["reserved_room_type"])
test_final["assigned_room_type"]=model1.fit_transform(test_final["assigned_room_type"])
test_final["deposit_type"]=model1.fit_transform(test_final["deposit_type"])
test_final["customer_type"]=model1.fit_transform(test_final["customer_type"])
test_final["assigned_room_type"]=model1.fit_transform(test_final["assigned_room_type"])
test_final["assigned_room_type"]=model1.fit_transform(test_final["assigned_room_type"])
test_final["reservation_status_date"]=model1.fit_transform(test_final["reservation_status_date"])
test_final["hotel"]=model1.fit_transform(test_final["hotel"])

# %%
from sklearn.preprocessing import MinMaxScaler
model3=MinMaxScaler()
xx_columns=test_final.columns
xx_new=model3.fit_transform(test_final)
xx_new=pd.DataFrame(xx_new,columns=xx_columns)

# %%
x=
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 0      Resort Hotel          3               2016           February
# 1        City Hotel         50               2016           November
# 2        City Hotel         14               2015          September
# 3        City Hotel         18               2015           December
# 4        City Hotel        263               2016          September
# ...             ...        ...                ...                ...
# 44633    City Hotel         31               2017               June
# 44634  Resort Hotel        116               2015          September
# 44635    City Hotel         89               2017              April
# 44636    City Hotel        277               2016          September
# 44637    City Hotel         22               2015           November
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                             7                         12
# ...

# %%
print(f'Features shape: {x.shape}')
print(f'Classes distribution:\n{y.value_counts()}')
fig, ax = plt.subplots()

sns.countplot(train_data['is_canceled'], ax=ax, palette='gnuplot')
plt.show()
# Out:
# Features shape: (44638, 27)
# Classes distribution:
# 0    31354
# 1    13284
# Name: is_canceled, dtype: int64
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from imblearn.over_sampling import SMOTE
y=train_data["is_canceled"]
x=train_data.drop(["is_canceled"],axis=1)

os = SMOTE(random_state=0, k_neighbors=10)

columns = x.columns

os_data_X, os_data_y = os.fit_resample(x, y)
os_data_X = pd.DataFrame(os_data_X, columns = columns)
os_data_y = pd.DataFrame(os_data_y, columns = ['is_canceled'])

# %%
from sklearn.preprocessing import MinMaxScaler
model2=MinMaxScaler()
x_columns=train_data.columns
x_new=model2.fit_transform(os_data_X)
x_new=pd.DataFrame(x_new,columns=columns)

# %%
print(f'Features shape after SMOTE: {os_data_X.shape}')
print(f'Classes distribution after SMOTE:\n{os_data_y.value_counts()}')
# Out:
# Features shape after SMOTE: (62708, 27)
# Classes distribution after SMOTE:
# is_canceled
# 0              31354
# 1              31354
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_new, os_data_y, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score

scores = []
for i in range(1,15):
    score = {}
    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    answers = knn.predict(X_test) 
    
    score['k'] = i
    score['accuracy'] = accuracy_score(answers,y_test)
    score['recall'] = recall_score(answers,y_test)
    score['presicion'] = precision_score(answers,y_test)
    
    scores.append(score)

scores = pd.DataFrame(scores)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
knn = KNeighborsClassifier(7)
knn.fit(X_train,y_train)
answers=knn.predict(xx_new)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
df=pd.DataFrame(answers,columns=["is_canceled"])
df=df.reset_index()

# %%
df.to_csv("answers_hotel.csv", index=False)

# %%
scores.head(15)
# Out:
#      k  accuracy    recall  presicion
# 0    1  0.861070  0.851782   0.870256
# 1    2  0.854947  0.920794   0.772915
# 2    3  0.849589  0.852526   0.841079
# 3    4  0.846527  0.899342   0.776272
# 4    5  0.843401  0.852874   0.825458
# 5    6  0.842699  0.888235   0.779757
# 6    7  0.841551  0.852492   0.821456
# 7    8  0.839829  0.880617   0.781823
# 8    9  0.836257  0.848848   0.813452
# 9   10  0.834280  0.874454   0.776013
# 10  11  0.832302  0.848902   0.803641
# 11  12  0.831728  0.870360   0.774852
# 12  13  0.828411  0.844508   0.800026
# 13  14  0.827135  0.862511   0.773431

# %%
train_data.info()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      1            0          3               2016                   3
# 1      0            1         50               2016                   9
# 2      0            0         14               2015                  11
# 3      0            0         18               2015                   2
# 4      0            1        263               2016                  11
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                         7                         12
# 1                        47                         18
# 2                        37                          7
# 3                        50                          6
# 4                        40                         29
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     2       2  ...
# 1                        1                     2       2  ...
# ...
