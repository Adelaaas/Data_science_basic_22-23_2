# %%
# !pip install opendatasets
import opendatasets as od
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import pandas as pd

# %%
od.download("https://www.kaggle.com/competitions/laptop-price-prediction-misis/")
# Out:
# ...
# 100%|██████████| 29.1k/29.1k [00:00<00:00, 14.5MB/s]
# Extracting archive ./laptop-price-prediction-misis/laptop-price-prediction-misis.zip to ./laptop-price-prediction-misis

# %%
train= pd.read_csv("/content/laptop-price-prediction-misis/Price_euros_train.csv")
train
# Out:
#       laptop_ID Company                                    Product  \
# 0             2   Apple                                Macbook Air
# 1             4   Apple                                MacBook Pro
# 2             5   Apple                                MacBook Pro
# 3             6    Acer                                   Aspire 3
# 4             7   Apple                                MacBook Pro
# ...         ...     ...                                        ...
# 1103       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1104       1316  Lenovo                             Yoga 500-14ISK
# 1105       1318  Lenovo                         IdeaPad 100S-14IBR
# 1106       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1107       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                           ScreenResolution  \
# 0              Ultrabook    13.3                                   1440x900
# ...

# %%
train=train.drop(['laptop_ID'],axis=1)

# %%
train
# Out:
#      Company                                    Product            TypeName  \
# 0      Apple                                Macbook Air           Ultrabook
# 1      Apple                                MacBook Pro           Ultrabook
# 2      Apple                                MacBook Pro           Ultrabook
# 3       Acer                                   Aspire 3            Notebook
# 4      Apple                                MacBook Pro           Ultrabook
# ...      ...                                        ...                 ...
# 1103    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1104  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1105  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1106      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1107    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
train['Weight'] = train['Weight'].fillna("2.2kg")

# %%
train['ScreenResolution'] = train['ScreenResolution'].fillna("Full HD 1920x1080")

# %%
train['OpSys'] = train['OpSys'].fillna("Windows 10")

# %%
for i in range(0,1108):
  train['Ram'][i]=train['Ram'][i][-3::-1]
  train['Ram'][i]=train['Ram'][i][::-1]
train['Ram']=pd.to_numeric(train['Ram'])
# Out:
# <ipython-input-272-841c181eb1c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Ram'][i]=train['Ram'][i][-3::-1]
# <ipython-input-272-841c181eb1c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Ram'][i]=train['Ram'][i][::-1]

# %%
for i in range(0,1108):
  train['Weight'][i]=train['Weight'][i][-3::-1]
  train['Weight'][i]=train['Weight'][i][::-1]
train['Weight']=pd.to_numeric(train['Weight'])
# Out:
# <ipython-input-273-6804783ab8ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Weight'][i]=train['Weight'][i][-3::-1]
# <ipython-input-273-6804783ab8ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Weight'][i]=train['Weight'][i][::-1]

# %%
train
# Out:
#       Company  Product  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0           1      269         4    13.3                 1   60    8       2
# 1           1      268         4    15.4                11   81   16      29
# 2           1      268         4    13.3                 9   64    8      16
# 3           0       51         3    15.6                 0   14    4      26
# 4           1      268         4    15.4                11   80   16      15
# ...       ...      ...       ...     ...               ...  ...  ...     ...
# 1103        2      505         3    15.6                 0   85    4      26
# 1104        9      514         0    14.0                 3   85    4       4
# 1105        9      176         3    14.0                 0   33    2      33
# 1106        7        2         3    15.6                 0   85    6      10
# 1107        2      503         3    15.6                 0   33    4      26
#
#       Gpu  OpSys  Weight  Price_euros
# ...

# %%
train.isna().sum()
# Out:
# Company              0
# Product              0
# TypeName             0
# Inches               0
# ScreenResolution    11
# Cpu                  0
# Ram                  0
# Memory               0
# Gpu                  0
# OpSys               53
# Weight               0
# Price_euros          0
# dtype: int64

# %%
train["OpSys"].value_counts()
# Out:
# Windows 10      864
# No OS            55
# Linux            53
# Windows 7        35
# Chrome OS        25
# macOS             8
# Mac OS X          7
# Windows 10 S      6
# Android           2
# Name: OpSys, dtype: int64

# %%
fl=0
for i in range(0,1108):
  l=len(train['ScreenResolution'][i])
  fl=0
  for j in range(0,l):
    if((train['ScreenResolution'][i][j]=='1' or  train['ScreenResolution'][i][j]=='2' or train['ScreenResolution'][i][j]=='3') and fl==0):
      fl=1
      train['ScreenResolution'][i]=train['ScreenResolution'][i][j::]
      break
  print(train['ScreenResolution'][i])

# %%
a="qwertyuiop"
print(a[6::])
# Out:
# uiop

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1108 non-null   object
#  1   Product           1108 non-null   object
#  2   TypeName          1108 non-null   object
#  3   Inches            1108 non-null   float64
#  4   ScreenResolution  1108 non-null   object
#  5   Cpu               1108 non-null   object
#  6   Ram               1108 non-null   int64
#  7   Memory            1108 non-null   object
#  8   Gpu               1108 non-null   object
#  9   OpSys             1108 non-null   object
#  10  Weight            1108 non-null   float64
#  11  Price_euros       1108 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 104.0+ KB

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Company']) 
train['Company'] = label_encoder.transform(train['Company'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Product']) 
train['Product'] = label_encoder.transform(train['Product'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['TypeName']) 
train['TypeName'] = label_encoder.transform(train['TypeName'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Cpu']) 
train['Cpu'] = label_encoder.transform(train['Cpu'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Memory']) 
train['Memory'] = label_encoder.transform(train['Memory'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Ram']) 
train['Ram'] = label_encoder.transform(train['Ram'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Gpu']) 
train['Gpu'] = label_encoder.transform(train['Gpu'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['OpSys']) 
train['OpSys'] = label_encoder.transform(train['OpSys'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['ScreenResolution']) 
train['ScreenResolution'] = label_encoder.transform(train['ScreenResolution'])

# %%
label_encoder = preprocessing.LabelEncoder() 
label_encoder.fit(train['Weight']) 
train['Weight'] = label_encoder.transform(train['Weight'])

# %%
y=train["Price_euros"]
y
# Out:
# 0        898.94
# 1       2537.45
# 2       1803.60
# 3        400.00
# 4       2139.97
#          ...
# 1103     720.32
# 1104     638.00
# 1105     229.00
# 1106     764.00
# 1107     369.00
# Name: Price_euros, Length: 1108, dtype: float64

# %%
x=train.drop(["Price_euros"],axis=1)
x
# Out:
#       Company  Product  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0           1      269         4    13.3                 1   60    8       2
# 1           1      268         4    15.4                24   81    1      29
# 2           1      268         4    13.3                22   64    8      16
# 3           0       51         3    15.6                 0   14    5      26
# 4           1      268         4    15.4                24   80    1      15
# ...       ...      ...       ...     ...               ...  ...  ...     ...
# 1103        2      505         3    15.6                 0   85    5      26
# 1104        9      514         0    14.0                13   85    5       4
# 1105        9      176         3    14.0                 0   33    3      33
# 1106        7        2         3    15.6                 0   85    7      10
# 1107        2      503         3    15.6                 0   33    5      26
#
#       Gpu  OpSys  Weight
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
for i in range(0,1108):
  print(train['Ram'][i])

# %%
a="61GB"
a=a[-3::-1]
print(type(a))
a=int(a)
print(type(a))
a
# Out:
# <class 'str'>
# <class 'int'>
# 16

# %%
train.isna().sum()
# Out:
# laptop_ID            0
# Company              0
# Product              0
# TypeName             0
# Inches               0
# ScreenResolution    11
# Cpu                  0
# Ram                  0
# Memory               0
# Gpu                  0
# OpSys               53
# Weight              22
# Price_euros          0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10), dpi= 80)
sns.heatmap(train.corr(), xticklabels=train.corr().columns, yticklabels=train.corr().columns, cmap='RdYlGn', center=0, annot=True)


plt.title('Матрица корреляции', fontsize=30)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
