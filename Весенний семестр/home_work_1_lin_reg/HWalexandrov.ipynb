# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

Dataf=pd.read_csv("/content/drive/MyDrive/critical-temperature-of-superconductors/train.csv")
Dataf=Dataf.drop(columns=["number_of_elements","range_Valence"])#Убираем target
x=Dataf.drop(columns=["critical_temp"])#Убираем не числа 
y=Dataf["critical_temp"]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
model = LinearRegression()
model.fit(X_train, y_train)
w0 = model.intercept_
w1 = model.coef_

# %%
Dataf.head(20)

# %%
result=""
result+=str(w0)
names=list(Dataf.columns)
names.pop()
for i in range(len(w1)):
  result+=" +"+" "+str(w1[i])+"*"+str(names[i])
result
#множество элементов имеет прямо пропорциональную связь wtd_gmean_atomic_mass, wtd_entropy_fie(выброс)
#присутсвуют обратно пропорциональные элементы wtd_mean_fie, entropy_atomic_mass(выброс), wtd_entropy_atomic_mass
# Out:
# '-26.119577960545072 + 0.9508715342646535*mean_atomic_mass + -1.022039319479953*wtd_mean_atomic_mass + -0.6026647406152958*gmean_atomic_mass + 0.7445551879241759*wtd_gmean_atomic_mass + -32.03590746799054*entropy_atomic_mass + 2.5408951224049288*wtd_entropy_atomic_mass + 0.24364717278277837*range_atomic_mass + 0.03062718890105777*wtd_range_atomic_mass + -0.660275629196518*std_atomic_mass + 0.12526566298544237*wtd_std_atomic_mass + 0.1562872461017182*mean_fie + -0.24300798504278057*wtd_mean_fie + -0.1423757650825006*gmean_fie + 0.2581912896863934*wtd_gmean_fie + -154.44073087844038*entropy_fie + 45.970729161167014*wtd_entropy_fie + 0.06398864898687034*range_fie + 0.023476592143154867*wtd_range_fie + -0.18518929031806353*std_fie + -0.016706425550806592*wtd_std_fie + -0.6005351457826605*mean_atomic_radius + 3.467856731378829*wtd_mean_atomic_radius + 0.2676113116933467*gmean_atomic_radius + -3.063432718207087*wtd_gmean_atomic_radius + 93.05618813681801*entropy_atomic_radius + 44.71921835313832*wtd_entropy_atomic_radius + 0.1629534802892172*range_atomic_radius + -0.1151632110600962*wtd_range_atomic_radius + -0.25446892277107397*std_atomic_radius + -0.368646999939809*wtd_std_atomic_radius + -0.00497178140166088*mean_Density + 0.00024876026946273055*wtd_mean_Density + 0.0013129265949267388*gmean_Density + 0.00209419537202038*wtd_gmean_Density + 11.543261457580261*entropy_Density + -18.558508613634057*wtd_entropy_Density + -0.0017020185049432257*range_Density + -2.750699727016581e-05*wtd_range_Density + 0.006265517784505903*std_Density + -0.0017617339692588274*wtd_std_Density + -0.02890215065457369*mean_ElectronAffinity + 0.4507388012496314*wtd_mean_ElectronAffinity + 0.10597721315069464*gmean_ElectronAffinity + -0.5066347084701199*wtd_gmean_ElectronAffinity + 7.392383223283093*entropy_ElectronAffinity + -22.34284134922005*wtd_entropy_ElectronAffinity + -0.38966078752259525*range_ElectronAffinity + -0.14163038585326504*wtd_range_ElectronAffinity + 1.253959858563194*std_ElectronAffinity + -0.4930337339294013*wtd_std_ElectronAffinity + 1.7669556210080763*mean_FusionHeat + -1.9348736878597665*wtd_mean_FusionHeat + -1.6468590953658193*gmean_FusionHeat + 1.6756091317388453*wtd_gmean_FusionHeat + -19.711185528244368*entropy_FusionHeat + 25.107924318024576*wtd_entropy_FusionHeat + -0.3577785427477096*range_FusionHeat + 0.5660277190579102*wtd_range_FusionHeat + -0.6580862075189415*std_FusionHeat + 0.8085343093428783*wtd_std_FusionHeat + -0.09097069924667522*mean_ThermalConductivity + 0.531894586683876*wtd_mean_ThermalConductivity + -0.049414684909315554*gmean_ThermalConductivity + -0.3191432151037361*wtd_gmean_ThermalConductivity + 13.715233264600203*entropy_ThermalConductivity + 2.0749418429791437*wtd_entropy_ThermalConductivity + -0.14061499389051946*range_ThermalConductivity + -0.24486828105818503*wtd_range_ThermalConductivity + 0.41558313513220924*std_ThermalConductivity + -0.0017887228668644894*wtd_std_ThermalConductivity + -13.322171454268952*mean_Valence + 26.02290914869395*wtd_mean_Valence + 17.775111080955085*gmean_Valence + -30.59847072757509*wtd_gmean_Valence + 89.32679267923498*entropy_Valence + -73.23359286807005*wtd_entropy_Valence + -0.6470730090870741*wtd_range_Valence + 18.837781907772563*std_Valence + -27.280666546542204*wtd_std_Valence'

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test["wtd_range_fie"], y_test)
plt.plot(X_test, y_pred, color='red', linewidth=1);
plt.show()

# %%
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))#MAE велик, поэтому высока вероятность ошибки
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))#MSE 312 значит один или более прогнозов сильно отличается (большое значение из-за возведения в квадрат)
print('R2 score:', r2_score(y_test, y_pred))#модель функионирует нормально, т.к. R2 находится в промежутке от 0 до 1
# Out:
# Mean Absolute Error: 13.4432537821411
# Mean Squared Error: 314.25131254370797
# R2 score: 0.7360461780543865
