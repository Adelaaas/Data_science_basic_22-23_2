# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

Dataf=pd.read_csv("/content/drive/MyDrive/critical-temperature-of-superconductors/train.csv")#атомная масса, энергия ионизации, радиус атома, плотность, удельная теплота плавления, энергия сродства к электрону, теплопроводность, валентность.
Dataf.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %%
x=Dataf.drop(columns=["critical_temp","std_FusionHeat","wtd_entropy_FusionHeat", 'gmean_ThermalConductivity','wtd_gmean_ThermalConductivity','wtd_range_Valence','std_Valence','wtd_mean_ThermalConductivity','range_FusionHeat','wtd_gmean_ElectronAffinity','wtd_mean_ThermalConductivity','mean_ThermalConductivity'])#убираем линейно-независимые признаки от target
y=Dataf["critical_temp"]

# %%
y=kx+b+k1x1+k2X2+...+knxn

# %%
import seaborn as sns
plt.figure(figsize=(50,30), dpi= 80)
sns.heatmap(Dataf.corr(), xticklabels=Dataf.corr().columns, yticklabels=Dataf.corr().columns, cmap='RdYlGn', center=0, annot=True)


plt.title('Матрица корреляции', fontsize=30)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
model = LinearRegression()
model.fit(X_train, y_train)
w0 = model.intercept_
w1 = model.coef_

# %%
Dataf.head(20)
# Out:
#     number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                    4         88.944468             57.862692
# 1                    5         92.729214             58.518416
# 2                    4         88.944468             57.885242
# 3                    4         88.944468             57.873967
# 4                    4         88.944468             57.840143
# 5                    4         88.944468             57.795044
# 6                    4         88.944468             57.682296
# 7                    4         76.517718             57.175142
# 8                    4         76.517718             56.808817
# 9                    4         76.517718             56.442492
# 10                   4         76.517718             55.709843
# 11                   5        111.273574             63.713457
# 12                   5         92.729214             58.201829
# 13                   5         92.729214             58.518416
# ...

# %%
result=""
result+=str(w0)
names=list(Dataf.columns)
names.pop()
for i in range(len(w1)):
  result+=" +"+" "+str(w1[i])+"*"+str(names[i])
result
#множество элементов имеет прямо пропорциональную связь wtd_gmean_atomic_mass, wtd_entropy_fie(выброс)
#присутсвуют обратно пропорциональные элементы wtd_mean_fie, entropy_atomic_mass(выброс), wtd_entropy_atomic_mass
# Out:
# '-20.17037667329246 + -1.319491762080869*number_of_elements + 0.9819326653674784*mean_atomic_mass + -1.1383426084916024*wtd_mean_atomic_mass + -0.5009741688259116*gmean_atomic_mass + 0.7270583265712605*wtd_gmean_atomic_mass + -26.339540122899702*entropy_atomic_mass + -2.4785186843307696*wtd_entropy_atomic_mass + 0.22466872268740135*range_atomic_mass + 0.08527875127585105*wtd_range_atomic_mass + -0.4240862138581294*std_atomic_mass + -0.08800030069554764*wtd_std_atomic_mass + 0.3304504011888803*mean_fie + -0.7279215609300503*wtd_mean_fie + -0.2943736991107909*gmean_fie + 0.7161857815589272*wtd_gmean_fie + -169.83166231995705*entropy_fie + 47.81684458483363*wtd_entropy_fie + 0.05860370261049247*range_fie + 0.02337310229065337*wtd_range_fie + -0.21979089853659567*std_fie + 0.08122464119010198*wtd_std_fie + -0.5665191417929898*mean_atomic_radius + 3.8955552117607395*wtd_mean_atomic_radius + 0.1707859589191577*gmean_atomic_radius + -3.4153016843115878*wtd_gmean_atomic_radius + 74.266921365
# ...

# %%
len(names)
# Out:
# 81

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test['range_atomic_radius'], y_test)
plt.scatter(X_test['range_atomic_radius'], y_pred, color='red', linewidth=1);
plt.show()

# %%
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))#MAE велик, поэтому высока вероятность ошибки
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))#MSE 316 значит один или более прогнозов сильно отличается (большое значение из-за возведения в квадрат)
print('R2 score:', r2_score(y_test, y_pred))#модель функионирует нормально, т.к. R2 находится в промежутке от 0 до 1
# Out:
# Mean Absolute Error: 13.673470700499685
# Mean Squared Error: 316.82740368985446
# R2 score: 0.7261265130737615
