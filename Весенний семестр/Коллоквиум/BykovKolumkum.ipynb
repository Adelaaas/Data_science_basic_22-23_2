# %% [markdown]
# #Вариант 4.

# %% [markdown]
# Постройте матрицу корреляции для данного набора данных и сделайте по ней вывод.
# Подсчитайте пропуски в данных.
# Есть ли в вашем наборе данных категориальные признаки? Если да, то закодируйте любой из них с использованием get_dummies().

# %%
import pandas
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/%D0%92%D0%B5%D1%81%D0%B5%D0%BD%D0%BD%D0%B8%D0%B9%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/%D0%9A%D0%BE%D0%BB%D0%BB%D0%BE%D0%BA%D0%B2%D0%B8%D1%83%D0%BC/segmentation%20data%20(1).csv")
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# ...

# %%
plt.scatter(df['Education'], df['Income'])
plt.show()

# %%
df.iloc[53:63].drop(columns = ['ID', 'Sex', 'Marital status', 'Occupation', 'Settlement size'])
# Out:
#     Age  Education  Income
# 53   31          0  117158
# 54   57          2  135830
# 55   26          0   58258
# 56   52          1  202575
# 57   31          1  183657
# 58   23          1  152267
# 59   23          1  115240
# 60   27          1  106955
# 61   50          1  123641
# 62   61          2  166410

# %%
df_copy = df.copy()

# %%
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Multipy
# 0                   2        2
# ...

# %%
df_copy['Multipy'] = df_copy['Occupation'] * df_copy['Settlement size']
df_copy
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Multipy
# 0                   2        2
# ...

# %% [markdown]
# # 1) Постройте матрицу корреляции для данного набора данных и сделайте по ней вывод.

# %%
corr = df.corr()

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e6a79_row0_col0, #T_e6a79_row1_col1, #T_e6a79_row2_col2, #T_e6a79_row3_col3, #T_e6a79_row4_col4, #T_e6a79_row5_col5, #T_e6a79_row6_col6, #T_e6a79_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e6a79_row0_col1, #T_e6a79_row4_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e6a79_row0_col2, #T_e6a79_row1_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e6a79_row0_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e6a79_row0_col4, #T_e6a79_row0_col5, #T_e6a79_row0_col6, #T_e6a79_row0_col7, #T_e6a79_row2_col3, #T_e6a79_row3_col2, #T_e6a79_row7_col0, #T_e6a79_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e6a79_row1_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e6a79_row1_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_e6a79_row1_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e6a79_row1_col5 {
# ...

# %% [markdown]
# Есть признаки, которые сильно кореллируют (Age и Education; Settlement size и Occupation; Occupation и Income; Sex и Martial status)

# %%
corr
# Out:
#                        ID       Sex  Marital status       Age  Education  \
# ID               1.000000  0.328262        0.074403 -0.085246   0.012543
# Sex              0.328262  1.000000        0.566511 -0.182885   0.244838
# Marital status   0.074403  0.566511        1.000000 -0.213178   0.374017
# Age             -0.085246 -0.182885       -0.213178  1.000000   0.654605
# Education        0.012543  0.244838        0.374017  0.654605   1.000000
# Income          -0.303217 -0.195146       -0.073528  0.340610   0.233459
# Occupation      -0.291958 -0.202491       -0.029490  0.108388   0.064524
# Settlement size -0.378445 -0.300803       -0.097041  0.119751   0.034732
#
#                    Income  Occupation  Settlement size
# ID              -0.303217   -0.291958        -0.378445
# Sex             -0.195146   -0.202491        -0.300803
# Marital status  -0.073528   -0.029490        -0.097041
# Age              0.340610    0.108388         0.119751
# ...

# %%
for i, item in enumerate(corr.loc['Settlement size']):
  if item > 0.4:
    print(corr.keys()[i])
# Out:
# Income
# Occupation
# Settlement size

# %% [markdown]
# # 2) Подсчитайте пропуски в данных.

# %%
df.isna().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %% [markdown]
# # 3) Есть ли в вашем наборе данных категориальные признаки? Если да, то закодируйте любой из них с использованием get_dummies().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   int64
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   int64
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   int64
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(8)
# memory usage: 125.1 KB

# %%
for i in df.keys():
  print(df[i].value_counts())
# Out:
# 100000001    1
# 100001330    1
# 100001343    1
# 100001342    1
# 100001341    1
#             ..
# 100000662    1
# 100000661    1
# 100000660    1
# 100000659    1
# 100002000    1
# Name: ID, Length: 2000, dtype: int64
# 0    1086
# 1     914
# Name: Sex, dtype: int64
# 0    1007
# 1     993
# Name: Marital status, dtype: int64
# 26    116
# 27    111
# 25     88
# 24     83
# 28     80
# 35     79
# 23     77
# 31     76
# 36     73
# 29     70
# 30     70
# 32     67
# 33     66
# 34     60
# 40     58
# 37     56
# 38     51
# 22     49
# 42     48
# 39     40
# 46     35
# 21     34
# 41     33
# 43     33
# 45     31
# 44     30
# 49     29
# 48     29
# 47     26
# 50     23
# 20     23
# 57     20
# 52     19
# 51     19
# 54     17
# 53     16
# 63     15
# 64     14
# 60     13
# 61     13
# 65     12
# 58     12
# 55     10
# 67     10
# 56     10
# 66      9
# 62      8
# 68      7
# 19      5
# 59      5
# 71      5
# 74      4
# 70      3
# 73      3
# 18      3
# ...

# %%
pd.get_dummies(df, columns=['Sex', 'Education', 'Occupation', 'Settlement size'])
# Out:
#              ID  Marital status  Age  Income  Sex_0  Sex_1  Education_0  \
# 0     100000001               0   67  124670      1      0            0
# 1     100000002               1   22  150773      0      1            0
# 2     100000003               0   49   89210      1      0            0
# 3     100000004               0   45  171565      1      0            0
# 4     100000005               0   53  149031      1      0            0
# ...         ...             ...  ...     ...    ...    ...          ...
# 1995  100001996               0   47  123525      0      1            0
# 1996  100001997               1   27  117744      0      1            0
# 1997  100001998               0   31   86400      1      0            1
# 1998  100001999               1   24   97968      0      1            0
# 1999  100002000               0   25   68416      1      0            1
#
#       Education_1  Education_2  Education_3  Occupation_0  Occupation_1  \
# ...
