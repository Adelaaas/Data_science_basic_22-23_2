# %% [markdown]
# #Вариант 5

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/%D0%92%D0%B5%D1%81%D0%B5%D0%BD%D0%BD%D0%B8%D0%B9%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/%D0%9A%D0%BE%D0%BB%D0%BB%D0%BE%D0%BA%D0%B2%D0%B8%D1%83%D0%BC/segmentation%20data%20(1).csv")

# %%
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
# Дендрограмма получится слишком большая, поэтому отсечём несколько данных.
X = df.iloc[:,:-3]
X
# Out:
#              ID  Sex  Marital status  Age  Education
# 0     100000001    0               0   67          2
# 1     100000002    1               1   22          1
# 2     100000003    0               0   49          1
# 3     100000004    0               0   45          1
# 4     100000005    0               0   53          1
# ...         ...  ...             ...  ...        ...
# 1995  100001996    1               0   47          1
# 1996  100001997    1               1   27          1
# 1997  100001998    0               0   31          0
# 1998  100001999    1               1   24          1
# 1999  100002000    0               0   25          0
#
# [2000 rows x 5 columns]

# %% [markdown]
# #Задание 1

# %%
# Создание матрицы расстояний
Z = linkage(X, 'ward')

# Визуализация данных
fig = plt.figure(figsize=(10, 10))
dn = dendrogram(Z)

# %% [markdown]
# #Задание 2

# %%
one = df[df["Education"] == 1]
two = df[df["Education"] == 2]
print("0: ", (df["Education"].sum() - one["Education"].sum() - two["Education"].sum()))
print("1: ", one["Education"].sum())
print("2: ", two["Education"].sum())
# Out:
# 0:  108
# 1:  1386
# 2:  582

# %% [markdown]
# #Задание 3

# %%
x = df["Age"]
y = df["Income"]

fig, ax = plt.subplots()

ax.scatter(x, y)

plt.title("Линейная зависимость y = x") 
plt.xlabel("Age")        
plt.ylabel("Income")

plt.show()
