# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/%D0%92%D0%B5%D1%81%D0%B5%D0%BD%D0%BD%D0%B8%D0%B9%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/%D0%9A%D0%BE%D0%BB%D0%BB%D0%BE%D0%BA%D0%B2%D0%B8%D1%83%D0%BC/train_oil.csv")
df.columns = df.columns.str.replace('Hydrocarbon type', 'Hydrocarbon_type')
df
# Out:
#             Field name                  Reservoir unit           Country  \
# 0              ZHIRNOV                     MELEKESKIAN            RUSSIA
# 1          LAGOA PARDA         LAGOA PARDA (URUCUTUCA)            BRAZIL
# 2               ABQAIQ                          ARAB D      SAUDI ARABIA
# 3            MURCHISON                           BRENT        UK /NORWAY
# 4         WEST PEMBINA          NISKU (PEMBINA L POOL)            CANADA
# ..                 ...                             ...               ...
# 304              HIDES                     IMBURU-TORO  PAPUA NEW GUINEA
# 305        DRAKE POINT      DRAKE POINT-INTREPID INLET            CANADA
# 306  ALTAMONT-BLUEBELL  GREEN RIVER AND COLTON/WASATCH               USA
# 307         BELL CREEK                           MUDDY               USA
# 308          WELL DRAW         MESAVERDE (TEAPOT SAND)               USA
#
#                   Region          Basin name  \
# ...

# %%
df.isna().sum()
# Out:
# Field name                         0
# Reservoir unit                     0
# Country                           27
# Region                            38
# Basin name                        38
# Tectonic regime                    0
# Latitude                          27
# Longitude                         30
# Operator company                   0
# Onshore/Offshore                   0
# Hydrocarbon_type                   0
# Reservoir status                   0
# Structural setting                 0
# Depth                              0
# Reservoir period                   0
# Lithology                          0
# Thickness (gross average ft)       0
# Thickness (net pay average ft)     0
# Porosity                           0
# Permeability                       0
# dtype: int64

# %%
#в таблице нет пропусков
df.Hydrocarbon_type.nunique()
#в колонке "Hydrocarbon_type" 4 уникальных значений
# Out:
# 4

# %%
df['Hydrocarbon_type'].value_counts()\
                 .sort_index(ascending=False)\
                 .sort_values(ascending=False)
# Out:
# OIL               231
# GAS                46
# GAS-CONDENSATE     30
# CARBON DIOXIDE      2
# Name: Hydrocarbon_type, dtype: int64

# %%
#from sklearn.preprocessing import LabelEncoder# Instatniate LabelEncoder
#le = LabelEncoder()
#df["Hydrocarbon_type"] = le.fit_transform(df["Hydrocarbon_type"])

pd.get_dummies (df, columns=['Hydrocarbon_type'], drop_first= True )
# Out:
#             Field name                  Reservoir unit           Country  \
# 0              ZHIRNOV                     MELEKESKIAN            RUSSIA
# 1          LAGOA PARDA         LAGOA PARDA (URUCUTUCA)            BRAZIL
# 2               ABQAIQ                          ARAB D      SAUDI ARABIA
# 3            MURCHISON                           BRENT        UK /NORWAY
# 4         WEST PEMBINA          NISKU (PEMBINA L POOL)            CANADA
# ..                 ...                             ...               ...
# 304              HIDES                     IMBURU-TORO  PAPUA NEW GUINEA
# 305        DRAKE POINT      DRAKE POINT-INTREPID INLET            CANADA
# 306  ALTAMONT-BLUEBELL  GREEN RIVER AND COLTON/WASATCH               USA
# 307         BELL CREEK                           MUDDY               USA
# 308          WELL DRAW         MESAVERDE (TEAPOT SAND)               USA
#
#                   Region          Basin name  \
# ...
