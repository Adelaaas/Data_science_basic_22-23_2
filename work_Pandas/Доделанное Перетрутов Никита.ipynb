# %% [markdown]
# # Домашнее задание

# %% [markdown]
# В домашнем задании вам необходимо рассмтреть данные с олимпиады НТИ по профилю "Исскусственный интеллект" за 2019-2020 год.
#
# Задачу можно найти по ссылке:
#
# https://www.kaggle.com/c/onti-students-performance/data

# %% [markdown]
# ## **Как загрузить данные в Google Colab?**
#
# 1. Из Github (файлы <25 МБ)
# 2. С локального диска
# 3. С Google Диска

# %%
# Github
# 1. Нажмите на файл с данными, которые хотите подключить
# 2. Нажмите "Raw"
# 3. Скопируйте ссылку открывшейся старницы
import pandas as pd

url1 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/X_train.csv'
url2 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/studs_info.csv'
url3 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/zachety.csv'
url4 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/y_train.csv'

X_train = pd.read_csv(url1)
studs_info = pd.read_csv(url2)
zachety = pd.read_csv(url3)
y_train = pd.read_csv(url4)

# %%
# С локального компьютера

from google.colab import files
uploaded = files.upload()

# %%
studs_info = pd.read_csv('studs_info.csv')
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
zachety = pd.read_csv('zachety.csv')

# %%
# Google disk

from google.colab import drive
drive.mount('/content/drive')

# %%
path = "copied path"
# /content/drive/MyDrive/Data Science для школьников/ОНТИ /ONTI Students performance/X_train.csv
df_bonus = pd.read_csv(path)

# %% [markdown]
# ## Вариант 1.

# %% [markdown]
# Кто делает:
# 1. Александров Данила Александрович
# 2. Быков Дмитрий Александрович
# 3. Горбунов Сергей Михайлович
# 4. Горячко Дарья Романовна
# 5. Громов Алексей Игоревич
# 6. Игнатов Константин Дмитриевич
# 7. Ямпольская Ирина Вадимовна
# 8. Дидковский Илья Радионович

# %% [markdown]
# 1. Посмотреть размерность дата фреймов.
# 2. Соедить два датафрейма X_train и y_train в один train по индексам.
# 3. Посчитать пропуски в получившемся датафрейме train.
# 4. Посчитать сколько раз встречается каждая специальность в колонке studs_info['направление (специальность)'].
# 5. Создать новый датафрейм из studs_info, в котором будут только женщины с лечебного дела.
# 6. Разложить колонку "Дата выпуска" на три: Год выпуска, Месяц выпуска, День выпуска.
# 7. Посчитать сколько уникальных значений в колонке studs_info['Категория обучения'].
# 8. Заменить в колонке studs_info['Категория обучения'] все строковые категории на числовые.
# 9. Удалить ненужную на ваш вгляд колонку из датафрейма studs_info.
# 10. Посчитать сколько мужчин выпустились 2019-08-31.

# %% [markdown]
# ## Вариант 2.

# %% [markdown]
# Кто делает:
# 1. Ивлиев Степан Дмитриевич
# 2. Игнатов Игорь Дмитриевич
# 3. Казанов Амир Ринатович
# 4. Клячин Иван Николаевич
# 5. Котов Александр Андреевич
# 6. Мелешкин Кирилл Андреевич
# 7. Файзуллин Илья Денисович
# 8. Чупрова Ася Александровна

# %% [markdown]
# 1. Посмотреть размерность дата фреймов.
# 2. Соедить два датафрейма X_train и y_train в один train по индексам.
# 3. Посчитать пропуски в датафрейме studs_info.
# 4. Посчитать сколько мужчин, сколько женщин в датафрейме studs_info.
# 5. Создать новый датафрейм из studs_info, в котором будут только мужчины 2019-06-30 года выпуска.
# 6. Разложить колонку "Дата выдачи" на четыре: Год выдачи, Месяц выдачи, День выдачи, Время выдачи.
# 7. Посчитать сколько уникальных значений в колонке studs_info['Статус'] и сколько раз каждое значение встречается в датафрейм.
# 8. Посчитать сколько раз какая оценка встречатся в датафрейм y_train.
# 9. Посчитать средний балл для студента с ID=175711 по всем предметам.
# 10. Удалить любую ненужны колонку на ваш вгляд из датафрейм train.

# %%
# Ваше решение

df[df['name'] == 'Ivan']

# %% [markdown]
# ## Вариант 3.

# %% [markdown]
# Кто делает:
# 1. Морозов Максим Олегович
# 2. Переттруов Никита Артемович
# 3. Пославский Егор Константинович
# 4. Садохин Константин Павлович
# 5. Скиданов Дмитрий Артёмович
# 6. Судариков Андрей Геннадьевич
# 7. Таланов Максим Андреевич

# %% [markdown]
# Задания:
# 1. Посмотреть размерность дата фреймов.
# 2. Соедить два датафрейма X_train и y_train в один train по индексам.
# 3. Посчитать пропуски в датафрейме studs_info.
# 4. Посчитать сколько уникальных значений в колонке АТТЕСТАЦИЯ и сколько раз каждое из них встречается.
# 5. Переименовать все колонки датафрейм train, чтобы названия были маленькими буквами.
# 6. Разложить колонку "направление" на две: Код направления, Название направления.
# 7. Создать новый датафрейм, в котором будут только мужчины 3 курса обучения.
# 8. Заменить все строковые значения в колонке Пол на числовые.
# 9. Сколько всего студентов сдавали предмет "Информатика" в виде экзамена? И какой средний балл по всем сдававшим?

# %% [markdown]
# №1

# %%
# задание номер 1
import pandas as pd
url1 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/X_train.csv'
url2 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/studs_info.csv'
url3 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/zachety.csv'
url4 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/y_train.csv'

X_train = pd.read_csv(url1)
studs_info = pd.read_csv(url2)
zachety = pd.read_csv(url3)
y_train = pd.read_csv(url4)
print(X_train.shape)
print(studs_info.shape)
print(zachety.shape)
print(y_train.shape)
# Out:
# (105058, 8)
# (5466, 13)
# (133223, 8)
# (105058, 2)

# %% [markdown]
# №2

# %%
final = pd.concat([y_train, X_train], axis=1)
final
# Out:
#          index  mark  Unnamed: 0  STD_ID             НАПРАВЛЕНИЕ        ГОД  \
# 0        51081     5       51081  175711     38.03.02 Менеджмент  2018-2019
# 1        72921     5       72921  100647  31.05.01 Лечебное дело  2015-2016
# 2        96438     5       96438  199311   31.05.03 Стоматология  2019-2020
# 3       273044     4      273044  162002     38.03.02 Менеджмент  2017-2018
# 4       371309     3      371309  108384  31.05.01 Лечебное дело  2018-2019
# ...        ...   ...         ...     ...                     ...        ...
# 105053  224856     3      224856  176141  40.03.01 Юриспруденция  2017-2018
# 105054  260998     3      260998  182794  31.05.01 Лечебное дело  2018-2019
# 105055   57245     4       57245  162391  31.05.01 Лечебное дело  2016-2017
# 105056  218529     4      218529  202479      38.03.01 Экономика  2017-2018
# 105057  233318     4      233318  182325  08.03.01 Строительство  2018-2019
#
#         КУРС  СЕМЕСТР                АТТЕСТАЦИЯ  \
# 0        2.0      4.0                   Экзамен
# 1        3.0      5.0                   Экзамен
# 2        1.0      1.0                   Экзамен
# 3        2.0      3.0                   Экзамен
# 4        5.0      9.0                   Экзамен
# ...      ...      ...                       ...
# 105053   1.0      2.0           Курсовая работа
# 105054   2.0      4.0                   Экзамен
# 105055   1.0      2.0  Дифференцированный зачет
# 105056   1.0      1.0  Дифференцированный зачет
# 105057   2.0      3.0           Курсовая работа
#
#                                                ДИСЦИПЛИНА
# 0                                               Маркетинг
# 1       Пропедевтика внутренних болезней, лучевая диаг...
# 2                                                   Химия
# 3                                              Статистика
# 4                                               Педиатрия
# ...                                                   ...
# 105053                              Конституционное право
# 105054                              Нормальная физиология
# 105055                                   Иностранный язык
# 105056                                        Информатика
# 105057           Технологические процессы в строительстве
#
# [105058 rows x 10 columns]

# %% [markdown]
# №3

# %%
studs_info.isna().sum()
# Out:
# STD_ID                            0
#    number                         1
# Пол                               1
# Статус                            1
# Дата выпуска                   5002
# Категория обучения                1
# Форма обучения                    1
# Шифр                              1
# направление (специальность)       1
#                                 191
# Образование                     191
# Дата выдачи                     240
# Что именно закончил             191
# dtype: int64

# %% [markdown]
# №4

# %%
final = pd.concat([y_train, X_train], axis=1)
x = len(final['АТТЕСТАЦИЯ'].unique())
print(final['АТТЕСТАЦИЯ'].value_counts())
print(x)
# Out:
# Экзамен                     60092
# Дифференцированный зачет    37791
# Курсовая работа              5522
# Курсовой проект              1631
# Зачет                          22
# Name: АТТЕСТАЦИЯ, dtype: int64
# 5

# %% [markdown]
# №5

# %%
final = final.rename(columns={'НАПРАВЛЕНИЕ' : 'направление','ГОД' : 'год','КУРС' : 'курс','СЕМЕСТР' : 'семестр','АТТЕСТАЦИЯ' : 'аттестация','ДИСЦИПЛИНА' : 'дисциплина'})
final
# Out:
#          index  mark  Unnamed: 0  STD_ID             направление        год  \
# 0        51081     5       51081  175711     38.03.02 Менеджмент  2018-2019
# 1        72921     5       72921  100647  31.05.01 Лечебное дело  2015-2016
# 2        96438     5       96438  199311   31.05.03 Стоматология  2019-2020
# 3       273044     4      273044  162002     38.03.02 Менеджмент  2017-2018
# 4       371309     3      371309  108384  31.05.01 Лечебное дело  2018-2019
# ...        ...   ...         ...     ...                     ...        ...
# 105053  224856     3      224856  176141  40.03.01 Юриспруденция  2017-2018
# 105054  260998     3      260998  182794  31.05.01 Лечебное дело  2018-2019
# 105055   57245     4       57245  162391  31.05.01 Лечебное дело  2016-2017
# 105056  218529     4      218529  202479      38.03.01 Экономика  2017-2018
# 105057  233318     4      233318  182325  08.03.01 Строительство  2018-2019
#
#         курс  семестр                аттестация  \
# 0        2.0      4.0                   Экзамен
# 1        3.0      5.0                   Экзамен
# 2        1.0      1.0                   Экзамен
# 3        2.0      3.0                   Экзамен
# 4        5.0      9.0                   Экзамен
# ...      ...      ...                       ...
# 105053   1.0      2.0           Курсовая работа
# 105054   2.0      4.0                   Экзамен
# 105055   1.0      2.0  Дифференцированный зачет
# 105056   1.0      1.0  Дифференцированный зачет
# 105057   2.0      3.0           Курсовая работа
#
#                                                дисциплина
# 0                                               Маркетинг
# 1       Пропедевтика внутренних болезней, лучевая диаг...
# 2                                                   Химия
# 3                                              Статистика
# 4                                               Педиатрия
# ...                                                   ...
# 105053                              Конституционное право
# 105054                              Нормальная физиология
# 105055                                   Иностранный язык
# 105056                                        Информатика
# 105057           Технологические процессы в строительстве
#
# [105058 rows x 10 columns]

# %% [markdown]
# №6

# %%
new_df = final['направление'].str.split(" ", 1, expand=True)
new_df.columns=['Код навправления','Название направления']
final = pd.concat([new_df, final], axis=1)
final.drop(['направление'], axis=1, inplace=True)
final
# Out:
#        Код навправления Название направления   index  mark  Unnamed: 0  \
# 0              38.03.02           Менеджмент   51081     5       51081
# 1              31.05.01        Лечебное дело   72921     5       72921
# 2              31.05.03         Стоматология   96438     5       96438
# 3              38.03.02           Менеджмент  273044     4      273044
# 4              31.05.01        Лечебное дело  371309     3      371309
# ...                 ...                  ...     ...   ...         ...
# 105053         40.03.01        Юриспруденция  224856     3      224856
# 105054         31.05.01        Лечебное дело  260998     3      260998
# 105055         31.05.01        Лечебное дело   57245     4       57245
# 105056         38.03.01            Экономика  218529     4      218529
# 105057         08.03.01        Строительство  233318     4      233318
#
#         STD_ID        год  курс  семестр                аттестация  \
# 0       175711  2018-2019   2.0      4.0                   Экзамен
# 1       100647  2015-2016   3.0      5.0                   Экзамен
# 2       199311  2019-2020   1.0      1.0                   Экзамен
# 3       162002  2017-2018   2.0      3.0                   Экзамен
# 4       108384  2018-2019   5.0      9.0                   Экзамен
# ...        ...        ...   ...      ...                       ...
# 105053  176141  2017-2018   1.0      2.0           Курсовая работа
# 105054  182794  2018-2019   2.0      4.0                   Экзамен
# 105055  162391  2016-2017   1.0      2.0  Дифференцированный зачет
# 105056  202479  2017-2018   1.0      1.0  Дифференцированный зачет
# 105057  182325  2018-2019   2.0      3.0           Курсовая работа
#
#                                                дисциплина
# 0                                               Маркетинг
# 1       Пропедевтика внутренних болезней, лучевая диаг...
# 2                                                   Химия
# 3                                              Статистика
# 4                                               Педиатрия
# ...                                                   ...
# 105053                              Конституционное право
# 105054                              Нормальная физиология
# 105055                                   Иностранный язык
# 105056                                        Информатика
# 105057           Технологические процессы в строительстве
#
# [105058 rows x 11 columns]

# %% [markdown]
# №7

# %%
male = studs_info[studs_info['Пол'] == "М"]
id = male['STD_ID'].values
zxc = final.loc[~final['STD_ID'].isin(id)]
finm = zxc[zxc['курс'] == 3.0]
finm
# Out:
#        Код навправления                         Название направления   index  \
# 1              31.05.01                                Лечебное дело   72921
# 25             31.05.01                                Лечебное дело  377876
# 26             40.03.01                                Юриспруденция  262326
# 27             44.03.01                   Педагогическое образование  265821
# 29             40.03.01                                Юриспруденция  302859
# ...                 ...                                          ...     ...
# 104999         31.05.01                                Лечебное дело   74999
# 105012         40.03.01                                Юриспруденция  332062
# 105014         44.03.03  Специальное (дефектологическое) образование  210503
# 105021         31.05.03                                 Стоматология  317607
# 105050         07.03.01                                  Архитектура   73409
#
#         mark  Unnamed: 0  STD_ID        год  курс  семестр  \
# 1          5       72921  100647  2015-2016   3.0      5.0
# 25         5      377876  120764  2016-2017   3.0      5.0
# 26         5      262326  182155  2019-2020   3.0      5.0
# 27         5      265821  170624  2018-2019   3.0      6.0
# 29         4      302859  165218  2018-2019   3.0      5.0
# ...      ...         ...     ...        ...   ...      ...
# 104999     3       74999  178356  2015-2016   3.0      6.0
# 105012     4      332062  120898  2017-2018   3.0      5.0
# 105014     4      210503  182260  2019-2020   3.0      5.0
# 105021     5      317607  165320  2018-2019   3.0      6.0
# 105050     4       73409   96954  2016-2017   3.0      6.0
#
#                       аттестация  \
# 1                        Экзамен
# 25                       Экзамен
# 26                       Экзамен
# 27                       Экзамен
# 29               Курсовая работа
# ...                          ...
# 104999                   Экзамен
# 105012           Курсовая работа
# 105014                   Экзамен
# 105021  Дифференцированный зачет
# 105050                   Экзамен
#
#                                                дисциплина
# 1       Пропедевтика внутренних болезней, лучевая диаг...
# 25      Общая хирургия, лучевая диагностика: общая хир...
# 26      Процессуальные особенности рассмотрения и разр...
# 27          Методика обучения русскому языку и литературе
# 29                                      Уголовный процесс
# ...                                                   ...
# 104999                                       Фармакология
# 105012                                  Уголовный процесс
# 105014  Образование лиц с нарушениями интеллекта: дошк...
# 105021  Практика производственная клиническая, в том ч...
# 105050  Архитектурное проектирование: архитектурное пр...
#
# [12231 rows x 11 columns]

# %% [markdown]
# №8

# %%
mapping = {'М': 0, 'Ж': 1}
studs_info.replace({'Пол': mapping})
# Out:
#       STD_ID     number  Пол Статус Дата выпуска Категория обучения  \
# 0      99136    13951.0  1.0    ВЫП   2019-08-31                 БП
# 1      99112    13998.0  1.0    ВЫП   2019-08-31                 БП
# 2      99109    13999.0  1.0    ВЫП   2019-08-31                 БП
# 3      99125    13953.0  1.0    ВЫП   2019-08-31                 БП
# 4     100676    13950.0  0.0    ВЫП   2019-08-31                 БП
# ...      ...        ...  ...    ...          ...                ...
# 5461  100678      978.0  1.0     СТ          NaN                 БП
# 5462  100663     1021.0  1.0     СТ          NaN                ДОГ
# 5463  191630     6447.0  1.0     СТ          NaN                ДОГ
# 5464  191625     3765.0  1.0     СТ          NaN                ДОГ
# 5465  194978     5245.0  1.0     СТ          NaN                ДОГ
#
#      Форма обучения      Шифр направление (специальность)         Образование  \
# 0                 Д  31.05.01               Лечебное дело  2629.0          СР
# 1                 Д  31.05.01               Лечебное дело  8240.0          СР
# 2                 Д  31.05.01               Лечебное дело  2314.0          СР
# 3                 Д  31.05.01               Лечебное дело  2345.0          СР
# 4                 Д  31.05.01               Лечебное дело  2650.0          СР
# ...             ...       ...                         ...     ...         ...
# 5461              Д  31.05.01               Лечебное дело  2388.0          СР
# 5462              Д  31.05.01               Лечебное дело  2554.0          СР
# 5463              Д  31.05.01               Лечебное дело  6692.0          СР
# 5464              Д  31.05.01               Лечебное дело     NaN         NaN
# 5465              Д  31.05.01               Лечебное дело     NaN         NaN
#
#               Дата выдачи        Что именно закончил
# 0     2013-06-26 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# 1     2012-06-23 00:00:00     МОУ СОШ N   2, ПЕСТОВО
# 2     2013-06-25 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# 3     2013-06-23 00:00:00        Гимназия "ГАРМОНИЯ"
# 4     2012-06-29 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# ...                   ...                        ...
# 5461  2013-06-21 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# 5462  2013-06-27 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# 5463  2014-05-31 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# 5464                  NaN                        NaN
# 5465                  NaN                        NaN
#
# [5466 rows x 13 columns]

# %% [markdown]
# №9

# %%
y = final[final['аттестация'] == 'Экзамен']
y = y[y['дисциплина'] == 'Информатика']
z = y.shape[0]
mark = y['mark'].sum() / z
print(z, mark)
# Out:
# 60 4.6
